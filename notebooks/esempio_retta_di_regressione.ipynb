# %% [markdown]
# <a href="https://colab.research.google.com/github/giovastabile/elaborazione_statistica/blob/main/esempio_retta_di_regressione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
(2087.8-68.6*30.2)/((4751.8-68.6**2)*(918.6-30.2**2))**(0.5)
# Out:
# 0.9272819801818807

# %%
eta = np.array([61,76,80,66,71,68,78,55,74,60,65,70,64,73,68])
peso = np.array([28,32,37,29,31,30,32,26,32,27,29,30,28,31,31])

x = np.linspace(55,90,100)
y = 0.35*x+6.19

print(x)

plt.plot(eta,peso,"*")
plt.plot(x,y,"-")
# Out:
# [55.         55.35353535 55.70707071 56.06060606 56.41414141 56.76767677
#  57.12121212 57.47474747 57.82828283 58.18181818 58.53535354 58.88888889
#  59.24242424 59.5959596  59.94949495 60.3030303  60.65656566 61.01010101
#  61.36363636 61.71717172 62.07070707 62.42424242 62.77777778 63.13131313
#  63.48484848 63.83838384 64.19191919 64.54545455 64.8989899  65.25252525
#  65.60606061 65.95959596 66.31313131 66.66666667 67.02020202 67.37373737
#  67.72727273 68.08080808 68.43434343 68.78787879 69.14141414 69.49494949
#  69.84848485 70.2020202  70.55555556 70.90909091 71.26262626 71.61616162
#  71.96969697 72.32323232 72.67676768 73.03030303 73.38383838 73.73737374
#  74.09090909 74.44444444 74.7979798  75.15151515 75.50505051 75.85858586
#  76.21212121 76.56565657 76.91919192 77.27272727 77.62626263 77.97979798
#  78.33333333 78.68686869 79.04040404 79.39393939 79.74747475 80.1010101
#  80.45454545 80.80808081 81.16161616 81.51515152 81.86868687 82.22222222
# ...

# %%
tempo = np.array([0,10,25,45,60,75,100,120])
N = np.array([470,653,1019,1720,3055,4812,10101,18646])
x = np.linspace(0,140,100)
y = 469.59*1.03**x

# %%
plt.plot(tempo,N,"*")
plt.plot(x,y,"-")

# %%
plt.semilogy(tempo,N,"o")
plt.semilogy(x,y,"-")
